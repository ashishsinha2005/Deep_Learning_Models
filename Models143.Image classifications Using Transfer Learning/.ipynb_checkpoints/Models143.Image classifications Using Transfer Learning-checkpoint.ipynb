jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_399.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_67.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_225.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_439.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_84.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_20.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_305.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_292.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_45.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_87.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_88.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_211.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_410.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_470.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_139.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_292.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_410.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_225.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_256.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_110.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_170.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_113.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_370.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_294.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_429.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_294.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_54.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_2.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_256.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_112.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_85.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_170.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_100x_422.jpg
# /kaggle/input/dataset/test/OSCC/OSCC_400x_331.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_83.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_149.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_65.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_119.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_72.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_88.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_104.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_2.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_25.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_162.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_155.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_35.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_43.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_41.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_38.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_89.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_12.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_74.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_54.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_152.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_21.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_124.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_130.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_96.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_122.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_197.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_105.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_12.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_150.jpg
# /kaggle/input/dataset/test/Normal/Normal_400x_106.jpg
# /kaggle/input/dataset/test/Normal/Normal_100x_22.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_100x_98.jpg
# /kaggle/input/dataset/train/OSCC/aug_641_9319.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_100x_1.jpg
# /kaggle/input/dataset/train/OSCC/aug_339_7209.jpg
# /kaggle/input/dataset/train/OSCC/aug_599_582.jpg
# /kaggle/input/dataset/train/OSCC/aug_275_8148.jpg
# /kaggle/input/dataset/train/OSCC/aug_427_8064.jpg
# /kaggle/input/dataset/train/OSCC/aug_165_8894.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_400x_210.jpg
# /kaggle/input/dataset/train/OSCC/aug_318_4013.jpg
# /kaggle/input/dataset/train/OSCC/aug_57_5803.jpg
# /kaggle/input/dataset/train/OSCC/aug_449_7136.jpg
# /kaggle/input/dataset/train/OSCC/aug_52_5924.jpg
# /kaggle/input/dataset/train/OSCC/aug_354_3168.jpg
# /kaggle/input/dataset/train/OSCC/aug_558_294.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_100x
jpg
# /kaggle/input/dataset/train/OSCC/OSCC_400x_68.jpg
# /kaggle/input/dataset/train/OSCC/aug_357_1039.jpg
# /kaggle/input/dataset/train/OSCC/aug_166_3747.jpg
# /kaggle/input/dataset/train/OSCC/aug_51_6185.jpg
# /kaggle/input/dataset/train/OSCC/aug_469_7704.jpg
# /kaggle/input/dataset/train/OSCC/aug_417_6827.jpg
# /kaggle/input/dataset/train/OSCC/aug_312_2773.jpg
# /kaggle/input/dataset/train/OSCC/aug_650_9951.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_100x_7.jpg
# /kaggle/input/dataset/train/OSCC/aug_55_6296.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_400x_160.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_400x_29.jpg
# /kaggle/input/dataset/train/OSCC/aug_201_6698.jpg
# /kaggle/input/dataset/train/OSCC/aug_440_3567.jpg
# /kaggle/input/dataset/train/OSCC/aug_136_6003.jpg
# /kaggle/input/dataset/train/OSCC/aug_9_726.jpg
# /kaggle/input/dataset/train/OSCC/aug_440_9838.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_400x_79.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_100x_193.jpg
# /kaggle/input/dataset/train/OSCC/OSCC_100x_50.jpg
# /kaggle/input/dataset/train/OSCC/aug_433_7967.jpg
# /kaggle/input/dataset/train/OSCC/aug_627_6130.jpg
# /kaggle/input/dataset/train/OSCC/aug_240_6893.jpg
# /kaggle/input/dataset/train/OSCC/aug_183_9371.jpg
# /kaggle/input/dataset/train/OSCC/aug_626_1123.jpg
# /kaggle/input/dataset/train/OSCC/aug_436_8654.jpg
# /kaggle/input/dataset/train/OSCC/aug_603_64.jpg
# /kaggle/input/dataset/train/OSCC/aug_185_3013.jpg
# /kaggle/input/dataset/train/OSCC/aug_689_6930.jpg
# ...
# /kaggle/input/dataset/train/Normal/aug_123_9125.jpg
# /kaggle/input/dataset/train/Normal/aug_627_4537.jpg
# /kaggle/input/dataset/train/Normal/aug_140_9995.jpg
# /kaggle/input/dataset/train/Normal/aug_68_4129.jpg
# /kaggle/input/dataset/train/Normal/aug_57_2664.jpg
# /kaggle/input/dataset/train/Normal/aug_51_8395.jpg
# /kaggle/input/dataset/train/Normal/aug_714_7724.jpg
# /kaggle/input/dataset/train/Normal/aug_314_6517.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_64.jpg
# /kaggle/input/dataset/train/Normal/aug_633_7829.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_179.jpg
# /kaggle/input/dataset/train/Normal/aug_56_4563.jpg
# /kaggle/input/dataset/train/Normal/aug_480_1837.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_165.jpg
# /kaggle/input/dataset/train/Normal/aug_18_1187.jpg
# /kaggle/input/dataset/train/Normal/aug_34_3493.jpg
# /kaggle/input/dataset/train/Normal/aug_38_4459.jpg
# /kaggle/input/dataset/train/Normal/aug_99_6294.jpg
# /kaggle/input/dataset/train/Normal/aug_89_6867.jpg
# /kaggle/input/dataset/train/Normal/aug_61_8620.jpg
# /kaggle/input/dataset/train/Normal/aug_205_5796.jpg
# /kaggle/input/dataset/train/Normal/aug_346_5244.jpg
# /kaggle/input/dataset/train/Normal/aug_91_2378.jpg
# /kaggle/input/dataset/train/Normal/aug_155_4219.jpg
# /kaggle/input/dataset/train/Normal/aug_108_405.jpg
# /kaggle/input/dataset/train/Normal/aug_179_5935.jpg
# /kaggle/input/dataset/train/Normal/aug_71_4747.jpg
# /kaggle/input/dataset/train/Normal/aug_22_9493.jpg
# /kaggle/input/dataset/train/Normal/aug_167_6758.jpg
# /kaggle/input/dataset/train/Normal/aug_37_5642.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_3.jpg
# /kaggle/input/dataset/train/Normal/aug_97_8152.jpg
# /kaggle/input/dataset/train/Normal/aug_71_2368.jpg
# /kaggle/input/dataset/train/Normal/aug_123_4682.jpg
# /kaggle/input/dataset/train/Normal/aug_197_7520.jpg
# /kaggle/input/dataset/train/Normal/aug_118_4709.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_25.jpg
# /kaggle/input/dataset/train/Normal/aug_177_8901.jpg
# /kaggle/input/dataset/train/Normal/aug_328_9791.jpg
# /kaggle/input/dataset/train/Normal/aug_51_5055.jpg
# /kaggle/input/dataset/train/Normal/aug_135_9777.jpg
# /kaggle/input/dataset/train/Normal/aug_171_9535.jpg
# /kaggle/input/dataset/train/Normal/aug_878_9950.jpg
# /kaggle/input/dataset/train/Normal/aug_723_1469.jpg
# /kaggle/input/dataset/train/Normal/aug_87_5665.jpg
# /kaggle/input/dataset/train/Normal/aug_134_4715.jpg
# /kaggle/input/dataset/train/Normal/aug_125_95.jpg
# /kaggle/input/dataset/train/Normal/aug_411_6643.jpg
# /kaggle/input/dataset/train/Normal/aug_391_3742.jpg
# /kaggle/input/dataset/train/Normal/aug_81_2455.jpg
# /kaggle/input/dataset/train/Normal/aug_217_9065.jpg
# /kaggle/input/dataset/train/Normal/aug_339_9757.jpg
# /kaggle/input/dataset/train/Normal/aug_62_7979.jpg
# /kaggle/input/dataset/train/Normal/aug_374_3233.jpg
# /kaggle/input/dataset/train/Normal/aug_148_4212.jpg
# /kaggle/input/dataset/train/Normal/aug_122_3979.jpg
# /kaggle/input/dataset/train/Normal/aug_210_4213.jpg
# /kaggle/input/dataset/train/Normal/aug_159_8731.jpg
# /kaggle/input/dataset/train/Normal/aug_267_8026.jpg
# /kaggle/input/dataset/train/Normal/aug_833_5238.jpg
# /kaggle/input/dataset/train/Normal/aug_6_551.jpg
# /kaggle/input/dataset/train/Normal/aug_27_807.jpg
# /kaggle/input/dataset/train/Normal/aug_722_8736.jpg
# /kaggle/input/dataset/train/Normal/aug_495_4862.jpg
# /kaggle/input/dataset/train/Normal/aug_206_9389.jpg
# /kaggle/input/dataset/train/Normal/aug_67_5316.jpg
# /kaggle/input/dataset/train/Normal/aug_206_5495.jpg
# /kaggle/input/dataset/train/Normal/aug_207_7244.jpg
# /kaggle/input/dataset/train/Normal/aug_210_9559.jpg
# /kaggle/input/dataset/train/Normal/aug_215_1577.jpg
# /kaggle/input/dataset/train/Normal/aug_18_7471.jpg
# /kaggle/input/dataset/train/Normal/aug_368_2287.jpg
# /kaggle/input/dataset/train/Normal/aug_18_3226.jpg
# /kaggle/input/dataset/train/Normal/aug_49_1734.jpg
# /kaggle/input/dataset/train/Normal/aug_3_2782.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_56.jpg
# /kaggle/input/dataset/train/Normal/aug_441_9329.jpg
# /kaggle/input/dataset/train/Normal/aug_258_9728.jpg
# /kaggle/input/dataset/train/Normal/aug_94_9966.jpg
# /kaggle/input/dataset/train/Normal/aug_479_9923.jpg
# /kaggle/input/dataset/train/Normal/aug_206_9046.jpg
# /kaggle/input/dataset/train/Normal/aug_372_8556.jpg
# /kaggle/input/dataset/train/Normal/aug_88_697.jpg
# /kaggle/input/dataset/train/Normal/aug_513_8637.jpg
# /kaggle/input/dataset/train/Normal/aug_37_4172.jpg
# /kaggle/input/dataset/train/Normal/aug_64_4671.jpg
# /kaggle/input/dataset/train/Normal/aug_185_1184.jpg
# /kaggle/input/dataset/train/Normal/aug_169_4033.jpg
# /kaggle/input/dataset/train/Normal/aug_333_4655.jpg
# /kaggle/input/dataset/train/Normal/aug_199_3129.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_17.jpg
# /kaggle/input/dataset/train/Normal/aug_96_8645.jpg
# /kaggle/input/dataset/train/Normal/aug_362_6151.jpg
# /kaggle/input/dataset/train/Normal/aug_88_3330.jpg
# /kaggle/input/dataset/train/Normal/aug_677_3187.jpg
# /kaggle/input/dataset/train/Normal/aug_875_1520.jpg
# /kaggle/input/dataset/train/Normal/aug_67_2461.jpg
# /kaggle/input/dataset/train/Normal/aug_47_7399.jpg
# /kaggle/input/dataset/train/Normal/aug_369_1341.jpg
# /kaggle/input/dataset/train/Normal/aug_176_2860.jpg
# /kaggle/input/dataset/train/Normal/aug_27_1661.jpg
# /kaggle/input/dataset/train/Normal/aug_181_3867.jpg
# /kaggle/input/dataset/train/Normal/aug_30_8704.jpg
# /kaggle/input/dataset/train/Normal/aug_96_8230.jpg
# /kaggle/input/dataset/train/Normal/aug_24_8749.jpg
# /kaggle/input/dataset/train/Normal/aug_797_9862.jpg
# /kaggle/input/dataset/train/Normal/aug_705_9714.jpg
# /kaggle/input/dataset/train/Normal/aug_226_4717.jpg
# /kaggle/input/dataset/train/Normal/aug_161_8311.jpg
# /kaggle/input/dataset/train/Normal/aug_834_8355.jpg
# /kaggle/input/dataset/train/Normal/aug_228_5117.jpg
# /kaggle/input/dataset/train/Normal/aug_132_847.jpg
# /kaggle/input/dataset/train/Normal/aug_205_2692.jpg
# /kaggle/input/dataset/train/Normal/aug_439_2172.jpg
# /kaggle/input/dataset/train/Normal/aug_679_6184.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_7.jpg
# /kaggle/input/dataset/train/Normal/aug_156_9078.jpg
# /kaggle/input/dataset/train/Normal/aug_46_4854.jpg
# /kaggle/input/dataset/train/Normal/aug_194_8729.jpg
# /kaggle/input/dataset/train/Normal/aug_22_9995.jpg
# /kaggle/input/dataset/train/Normal/aug_30_4160.jpg
# /kaggle/input/dataset/train/Normal/aug_207_5397.jpg
# /kaggle/input/dataset/train/Normal/aug_375_6891.jpg
# /kaggle/input/dataset/train/Normal/aug_110_9697.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_8.jpg
# /kaggle/input/dataset/train/Normal/aug_210_2563.jpg
# /kaggle/input/dataset/train/Normal/aug_66_7306.jpg
# /kaggle/input/dataset/train/Normal/aug_225_3537.jpg
# /kaggle/input/dataset/train/Normal/aug_6_365.jpg
# /kaggle/input/dataset/train/Normal/aug_419_4831.jpg
# /kaggle/input/dataset/train/Normal/aug_794_3393.jpg
# /kaggle/input/dataset/train/Normal/aug_131_7183.jpg
# /kaggle/input/dataset/train/Normal/aug_151_8097.jpg
# /kaggle/input/dataset/train/Normal/aug_126_4435.jpg
# /kaggle/input/dataset/train/Normal/aug_30_1352.jpg
# /kaggle/input/dataset/train/Normal/aug_36_742.jpg
# /kaggle/input/dataset/train/Normal/aug_195_1599.jpg
# /kaggle/input/dataset/train/Normal/aug_61_8473.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_33.jpg
# /kaggle/input/dataset/train/Normal/aug_654_518.jpg
# /kaggle/input/dataset/train/Normal/aug_208_2571.jpg
# /kaggle/input/dataset/train/Normal/aug_45_6211.jpg
# /kaggle/input/dataset/train/Normal/aug_160_1538.jpg
# /kaggle/input/dataset/train/Normal/aug_826_2964.jpg
# /kaggle/input/dataset/train/Normal/aug_624_8322.jpg
# /kaggle/input/dataset/train/Normal/aug_145_3113.jpg
# /kaggle/input/dataset/train/Normal/aug_165_3516.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_187.jpg
# /kaggle/input/dataset/train/Normal/aug_91_7609.jpg
# /kaggle/input/dataset/train/Normal/aug_373_9944.jpg
# /kaggle/input/dataset/train/Normal/aug_16_9240.jpg
# /kaggle/input/dataset/train/Normal/aug_100_5027.jpg
# /kaggle/input/dataset/train/Normal/aug_609_3304.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_101.jpg
# /kaggle/input/dataset/train/Normal/aug_245_6957.jpg
# /kaggle/input/dataset/train/Normal/aug_184_9462.jpg
# /kaggle/input/dataset/train/Normal/aug_80_1001.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_77.jpg
# /kaggle/input/dataset/train/Normal/aug_55_9088.jpg
# /kaggle/input/dataset/train/Normal/aug_61_1260.jpg
# /kaggle/input/dataset/train/Normal/aug_298_8282.jpg
# /kaggle/input/dataset/train/Normal/aug_193_603.jpg
# /kaggle/input/dataset/train/Normal/aug_196_2548.jpg
# /kaggle/input/dataset/train/Normal/aug_41_1712.jpg
# /kaggle/input/dataset/train/Normal/aug_1_477.jpg
# /kaggle/input/dataset/train/Normal/aug_183_7784.jpg
# /kaggle/input/dataset/train/Normal/aug_153_8955.jpg
# /kaggle/input/dataset/train/Normal/aug_79_4915.jpg
# /kaggle/input/dataset/train/Normal/aug_144_86.jpg
# /kaggle/input/dataset/train/Normal/aug_122_2347.jpg
# /kaggle/input/dataset/train/Normal/aug_380_8839.jpg
# /kaggle/input/dataset/train/Normal/aug_219_4777.jpg
# /kaggle/input/dataset/train/Normal/aug_105_9422.jpg
# /kaggle/input/dataset/train/Normal/aug_109_7809.jpg
# /kaggle/input/dataset/train/Normal/aug_94_6810.jpg
# /kaggle/input/dataset/train/Normal/aug_713_5011.jpg
# /kaggle/input/dataset/train/Normal/aug_322_9889.jpg
# /kaggle/input/dataset/train/Normal/aug_141_9846.jpg
# /kaggle/input/dataset/train/Normal/aug_9_5215.jpg
# /kaggle/input/dataset/train/Normal/aug_96_4094.jpg
# /kaggle/input/dataset/train/Normal/aug_224_1423.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_32.jpg
# /kaggle/input/dataset/train/Normal/aug_177_8322.jpg
# /kaggle/input/dataset/train/Normal/aug_7_716.jpg
# /kaggle/input/dataset/train/Normal/aug_11_2840.jpg
# /kaggle/input/dataset/train/Normal/aug_100_5774.jpg
# /kaggle/input/dataset/train/Normal/aug_73_9454.jpg
# /kaggle/input/dataset/train/Normal/aug_160_6838.jpg
# /kaggle/input/dataset/train/Normal/aug_14_7487.jpg
# /kaggle/input/dataset/train/Normal/aug_115_7670.jpg
# /kaggle/input/dataset/train/Normal/aug_662_531.jpg
# /kaggle/input/dataset/train/Normal/aug_213_6978.jpg
# /kaggle/input/dataset/train/Normal/aug_871_1264.jpg
# /kaggle/input/dataset/train/Normal/aug_216_687.jpg
# /kaggle/input/dataset/train/Normal/aug_92_2631.jpg
# /kaggle/input/dataset/train/Normal/aug_191_1567.jpg
# /kaggle/input/dataset/train/Normal/aug_5_7236.jpg
# /kaggle/input/dataset/train/Normal/aug_98_9920.jpg
# /kaggle/input/dataset/train/Normal/aug_64_2442.jpg
# /kaggle/input/dataset/train/Normal/aug_75_9296.jpg
# /kaggle/input/dataset/train/Normal/aug_10_4938.jpg
# /kaggle/input/dataset/train/Normal/aug_157_5741.jpg
# /kaggle/input/dataset/train/Normal/aug_186_2256.jpg
# /kaggle/input/dataset/train/Normal/aug_74_9498.jpg
# /kaggle/input/dataset/train/Normal/aug_128_4134.jpg
# /kaggle/input/dataset/train/Normal/aug_831_129.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_118.jpg
# /kaggle/input/dataset/train/Normal/aug_135_4158.jpg
# /kaggle/input/dataset/train/Normal/aug_204_4048.jpg
# /kaggle/input/dataset/train/Normal/aug_30_7428.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_39.jpg
# /kaggle/input/dataset/train/Normal/aug_220_7505.jpg
# /kaggle/input/dataset/train/Normal/aug_176_2384.jpg
# /kaggle/input/dataset/train/Normal/aug_645_9555.jpg
# /kaggle/input/dataset/train/Normal/aug_140_9886.jpg
# /kaggle/input/dataset/train/Normal/aug_80_2909.jpg
# /kaggle/input/dataset/train/Normal/aug_83_8395.jpg
# /kaggle/input/dataset/train/Normal/aug_188_8140.jpg
# /kaggle/input/dataset/train/Normal/aug_317_9853.jpg
# /kaggle/input/dataset/train/Normal/aug_56_2512.jpg
# /kaggle/input/dataset/train/Normal/aug_443_8525.jpg
# /kaggle/input/dataset/train/Normal/aug_228_4667.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_66.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_77.jpg
# /kaggle/input/dataset/train/Normal/aug_110_9788.jpg
# /kaggle/input/dataset/train/Normal/aug_69_383.jpg
# /kaggle/input/dataset/train/Normal/aug_129_7499.jpg
# /kaggle/input/dataset/train/Normal/aug_208_787.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_75.jpg
# /kaggle/input/dataset/train/Normal/aug_6_8337.jpg
# /kaggle/input/dataset/train/Normal/aug_576_8896.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_69.jpg
# /kaggle/input/dataset/train/Normal/aug_16_5780.jpg
# /kaggle/input/dataset/train/Normal/aug_162_1584.jpg
# /kaggle/input/dataset/train/Normal/aug_85_7596.jpg
# /kaggle/input/dataset/train/Normal/aug_164_6147.jpg
# /kaggle/input/dataset/train/Normal/aug_164_8877.jpg
# /kaggle/input/dataset/train/Normal/aug_193_3135.jpg
# /kaggle/input/dataset/train/Normal/aug_874_2278.jpg
# /kaggle/input/dataset/train/Normal/aug_184_9004.jpg
# /kaggle/input/dataset/train/Normal/aug_355_5834.jpg
# /kaggle/input/dataset/train/Normal/aug_858_9618.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_73.jpg
# /kaggle/input/dataset/train/Normal/aug_222_4665.jpg
# /kaggle/input/dataset/train/Normal/aug_95_9733.jpg
# /kaggle/input/dataset/train/Normal/aug_533_1632.jpg
# /kaggle/input/dataset/train/Normal/aug_559_5464.jpg
# /kaggle/input/dataset/train/Normal/aug_114_2811.jpg
# /kaggle/input/dataset/train/Normal/aug_56_6179.jpg
# /kaggle/input/dataset/train/Normal/aug_339_7816.jpg
# /kaggle/input/dataset/train/Normal/aug_23_242.jpg
# /kaggle/input/dataset/train/Normal/aug_78_1141.jpg
# /kaggle/input/dataset/train/Normal/aug_146_8448.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_19.jpg
# /kaggle/input/dataset/train/Normal/aug_279_410.jpg
# /kaggle/input/dataset/train/Normal/aug_158_2088.jpg
# /kaggle/input/dataset/train/Normal/aug_424_7602.jpg
# /kaggle/input/dataset/train/Normal/aug_87_5971.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_14.jpg
# /kaggle/input/dataset/train/Normal/aug_355_5811.jpg
# /kaggle/input/dataset/train/Normal/aug_246_7414.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_5.jpg
# /kaggle/input/dataset/train/Normal/aug_75_5736.jpg
# /kaggle/input/dataset/train/Normal/aug_203_5744.jpg
# /kaggle/input/dataset/train/Normal/aug_283_3433.jpg
# /kaggle/input/dataset/train/Normal/aug_843_6519.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_41.jpg
# /kaggle/input/dataset/train/Normal/aug_821_7650.jpg
# /kaggle/input/dataset/train/Normal/aug_14_2039.jpg
# /kaggle/input/dataset/train/Normal/aug_49_6615.jpg
# /kaggle/input/dataset/train/Normal/aug_187_4872.jpg
# /kaggle/input/dataset/train/Normal/aug_113_9522.jpg
# /kaggle/input/dataset/train/Normal/aug_221_8266.jpg
# /kaggle/input/dataset/train/Normal/aug_49_5639.jpg
# /kaggle/input/dataset/train/Normal/aug_36_8841.jpg
# /kaggle/input/dataset/train/Normal/aug_111_2328.jpg
# /kaggle/input/dataset/train/Normal/aug_130_3064.jpg
# /kaggle/input/dataset/train/Normal/aug_312_1878.jpg
# /kaggle/input/dataset/train/Normal/aug_176_1740.jpg
# /kaggle/input/dataset/train/Normal/aug_151_8237.jpg
# /kaggle/input/dataset/train/Normal/aug_41_7332.jpg
# /kaggle/input/dataset/train/Normal/aug_73_2399.jpg
# /kaggle/input/dataset/train/Normal/aug_180_5803.jpg
# /kaggle/input/dataset/train/Normal/aug_109_2001.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_125.jpg
# /kaggle/input/dataset/train/Normal/aug_23_2547.jpg
# /kaggle/input/dataset/train/Normal/aug_192_2281.jpg
# /kaggle/input/dataset/train/Normal/aug_171_9517.jpg
# /kaggle/input/dataset/train/Normal/aug_43_6197.jpg
# /kaggle/input/dataset/train/Normal/aug_375_7183.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_70.jpg
# /kaggle/input/dataset/train/Normal/aug_189_4543.jpg
# /kaggle/input/dataset/train/Normal/aug_132_5898.jpg
# /kaggle/input/dataset/train/Normal/aug_161_331.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_74.jpg
# /kaggle/input/dataset/train/Normal/aug_201_1701.jpg
# /kaggle/input/dataset/train/Normal/aug_139_2197.jpg
# /kaggle/input/dataset/train/Normal/aug_150_8437.jpg
# /kaggle/input/dataset/train/Normal/Normal_400x_56.jpg
# /kaggle/input/dataset/train/Normal/aug_88_7497.jpg
# /kaggle/input/dataset/train/Normal/aug_77_9140.jpg
# /kaggle/input/dataset/train/Normal/aug_14_9477.jpg
# /kaggle/input/dataset/train/Normal/aug_342_3398.jpg
# /kaggle/input/dataset/train/Normal/aug_135_5499.jpg
# /kaggle/input/dataset/train/Normal/aug_428_2859.jpg
# /kaggle/input/dataset/train/Normal/Normal_100x_20.jpg
# /kaggle/input/dataset/train/Normal/aug_212_9333.jpg
# /kaggle/input/dataset/train/Normal/aug_108_7767.jpg

# %%
dataset_path = "/kaggle/input/dataset/train"
categories = ["Normal", "OSCC"]

# %%
data = []

# %%
for category in categories:
    folder_path = os.path.join(dataset_path, category)
    label = category 
   
    for file_name in os.listdir(folder_path):
        if file_name.endswith(('.png', '.jpg', '.jpeg')):  
            file_path = os.path.join(folder_path, file_name)
            data.append([file_path, label])

# %%
df = pd.DataFrame(data, columns=["file_path", "label"])

# %%
df.head()
# Out:
#                                            file_path   label
# 0  /kaggle/input/dataset/train/Normal/aug_506_590...  Normal
# 1  /kaggle/input/dataset/train/Normal/aug_35_9199...  Normal
# 2  /kaggle/input/dataset/train/Normal/aug_263_936...  Normal
# 3  /kaggle/input/dataset/train/Normal/aug_432_454...  Normal
# 4  /kaggle/input/dataset/train/Normal/aug_70_904.jpg  Normal

# %%
df.tail()
# Out:
#                                               file_path label
# 4941   /kaggle/input/dataset/train/OSCC/aug_373_318.jpg  OSCC
# 4942  /kaggle/input/dataset/train/OSCC/aug_694_4500.jpg  OSCC
# 4943  /kaggle/input/dataset/train/OSCC/OSCC_100x_224...  OSCC
# 4944   /kaggle/input/dataset/train/OSCC/aug_36_9010.jpg  OSCC
# 4945  /kaggle/input/dataset/train/OSCC/aug_322_6065.jpg  OSCC

# %%
df.shape
# Out:
# (4946, 2)

# %%
df.columns
# Out:
# Index(['file_path', 'label'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# file_path    0
# label        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4946 entries, 0 to 4945
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_path  4946 non-null   object
#  1   label      4946 non-null   object
# dtypes: object(2)
# memory usage: 77.4+ KB

# %%
df['label'].unique()
# Out:
# array(['Normal', 'OSCC'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# OSCC      2511
# Normal    2435
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

category_counts = df['label'].value_counts()

plt.figure(figsize=(8, 6))
sns.countplot(x='label', data=df, palette='viridis')
plt.title('Distribution of Images by Category', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

plt.figure(figsize=(8, 6))
category_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon'])
plt.title('Category Distribution', fontsize=16)
plt.ylabel('')  
plt.show()

# %%
import cv2

num_samples = 5

fig, axes = plt.subplots(2, num_samples, figsize=(15, 6))

for i, category in enumerate(df['label'].unique()):
    
    category_images = df[df['label'] == category].head(num_samples)
    
    for j, image_path in enumerate(category_images['file_path']):
    
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    
        axes[i, j].imshow(img)
        axes[i, j].axis('off') 
        if j == 0:
            axes[i, j].set_ylabel(category, fontsize=14, rotation=90)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['Encoded_Label'] = label_encoder.fit_transform(df['label'])

label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Encoding Mapping:")
print(label_mapping)
# Out:
# Label Encoding Mapping:
# {'Normal': 0, 'OSCC': 1}

# %%
import time
import shutil
import pathlib
import itertools
from PIL import Image

import cv2
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

import warnings
warnings.filterwarnings("ignore")

print ('check')
# Out:
# check

# %%
df['Encoded_Label'] = df['Encoded_Label'].astype(str)

# %%
df.columns
# Out:
# Index(['file_path', 'label', 'Encoded_Label'], dtype='object')

# %%
df = df[['file_path', 'Encoded_Label']]

# %%
train_df_new, temp_df_new = train_test_split(
    df,
    train_size=0.8,  
    shuffle=True,
    random_state=42,
    stratify=df['Encoded_Label']  
)

valid_df_new, test_df_new = train_test_split(
    temp_df_new,
    test_size=0.5,  
    shuffle=True,
    random_state=42,
    stratify=temp_df_new['Encoded_Label'] 
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch_size = 16
img_size = (299, 299)  
channels = 3  
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator(rescale=1./255)  
ts_gen = ImageDataGenerator(rescale=1./255)

train_gen_new = tr_gen.flow_from_dataframe(
    df,
    x_col='file_path',
    y_col='Encoded_Label',
    target_size=img_size,  
    class_mode='binary',
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size
)

valid_gen_new = ts_gen.flow_from_dataframe(
    valid_df_new,
    x_col='file_path',  
    y_col='Encoded_Label',     
    target_size=img_size,  
    class_mode='binary',  
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size
)

test_gen_new = ts_gen.flow_from_dataframe(
    test_df_new,
    x_col='file_path', 
    y_col='Encoded_Label',    
    target_size=img_size,  
    class_mode='binary',  
    color_mode='rgb', 
    shuffle=False,  
    batch_size=batch_size
)
# Out:
# Found 4946 validated image filenames belonging to 2 classes.
# Found 495 validated image filenames belonging to 2 classes.
# Found 495 validated image filenames belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# Using GPU

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, 
    BatchNormalization, GaussianNoise, Input, 
    MultiHeadAttention, Reshape
)
from tensorflow.keras.optimizers import Adam

def create_xception_model(input_shape, num_classes=2, learning_rate=0.0001):
    inputs = Input(shape=input_shape, name="Input_Layer")
    base_model = Xception(weights='imagenet', input_tensor=inputs, include_top=False)
    base_model.trainable = False
    x = base_model.output
    height, width, channels = x.shape[1], x.shape[2], x.shape[3]
    x = Reshape((height * width, channels), name="Reshape_to_Sequence")(x)
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=channels, name="Multi_Head_Attention"
    )(x, x)
    attention_output = Reshape((height, width, channels), name="Reshape_to_Spatial")(attention_output)
    x = GaussianNoise(0.25, name="Gaussian_Noise_1")(attention_output)
    x = GlobalAveragePooling2D(name="Global_Avg_Pooling")(x)
    x = Dense(512, activation='relu', name="FC_512")(x)
    x = BatchNormalization(name="Batch_Normalization")(x)
    x = GaussianNoise(0.25, name="Gaussian_Noise_2")(x)
    x = Dropout(0.25, name="Dropout")(x)
    outputs = Dense(1, activation='sigmoid', name="Output_Layer")(x)
    model = Model(inputs=inputs, outputs=outputs, name="Xception_with_Attention")
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

input_shape = (299, 299, 3)
cnn_model = create_xception_model(input_shape, num_classes=2, learning_rate=0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
history = cnn_model.fit(
    train_gen_new,
    validation_data=valid_gen_new,
    epochs=5,  
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732441776.854039     106 service.cc:145] XLA service 0x7aa5f1096c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732441776.854099     106 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1732441776.854104     106 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732441786.817904     134 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_75', 228 bytes spill stores, 228 bytes spill loads
#
# I0000 00:00:1732441787.388886     136 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 1048 bytes spill stores, 1044 bytes spill loads
#
# I0000 00:00:1732441809.444929     106 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 143/310 ━━━━━━━━━━━━━━━━━━━━ 1:05 390ms/step - accuracy: 0.7248 - loss: 0.6269
# I0000 00:00:1732441875.353624     172 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_75', 228 bytes spill stores, 228 bytes spill loads
#
# I0000 00:00:1732441875.648364     170 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 1048 bytes spill stores, 1044 bytes spill loads
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.7519 - loss: 0.5595
# I0000 00:00:1732441971.309592     206 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 1048 bytes spill stores, 1044 bytes spill loads
#
# I0000 00:00:1732441973.039498     207 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 228 bytes spill stores, 228 bytes spill loads
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 220s 577ms/step - accuracy: 0.7520 - loss: 0.5592 - val_accuracy: 0.8061 - val_loss: 0.4536
# Epoch 2/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 137s 438ms/step - accuracy: 0.8478 - loss: 0.3550 - val_accuracy: 0.8990 - val_loss: 0.2516
# Epoch 3/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 137s 435ms/step - accuracy: 0.8802 - loss: 0.2863 - val_accuracy: 0.9212 - val_loss: 0.1860
# Epoch 4/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 137s 434ms/step - accuracy: 0.9030 - loss: 0.2368 - val_accuracy: 0.9556 - val_loss: 0.1198
# Epoch 5/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 136s 432ms/step - accuracy: 0.8988 - loss: 0.2392 - val_accuracy: 0.9535 - val_loss: 0.1314

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
report = classification_report(test_labels, predicted_classes, target_names=list(test_gen_new.class_indices.keys()))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       244
#            1       0.96      0.93      0.94       251
#
#     accuracy                           0.94       495
#    macro avg       0.94      0.94      0.94       495
# weighted avg       0.94      0.94      0.94       495

# %%
conf_matrix = confusion_matrix(test_labels, predicted_classes)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=list(test_gen_new.class_indices.keys()), yticklabels=list(test_gen_new.class_indices.keys()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, 
    BatchNormalization, GaussianNoise, Input, 
    MultiHeadAttention, Reshape
)
from tensorflow.keras.optimizers import Adam

def create_mobilenet_model(input_shape, num_classes=2, learning_rate=0.0001):
    inputs = Input(shape=input_shape, name="Input_Layer")
    base_model = MobileNet(weights='imagenet', input_tensor=inputs, include_top=False)
    base_model.trainable = False
    x = base_model.output
    height, width, channels = x.shape[1], x.shape[2], x.shape[3]
    x = Reshape((height * width, channels), name="Reshape_to_Sequence")(x)
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=channels, name="Multi_Head_Attention"
    )(x, x)
    attention_output = Reshape((height, width, channels), name="Reshape_to_Spatial")(attention_output)
    x = GaussianNoise(0.25, name="Gaussian_Noise_1")(attention_output)
    x = GlobalAveragePooling2D(name="Global_Avg_Pooling")(x)
    x = Dense(512, activation='relu', name="FC_512")(x)
    x = BatchNormalization(name="Batch_Normalization")(x)
    x = GaussianNoise(0.25, name="Gaussian_Noise_2")(x)
    x = Dropout(0.25, name="Dropout")(x)
    outputs = Dense(1, activation='sigmoid', name="Output_Layer")(x)
    model = Model(inputs=inputs, outputs=outputs, name="MobileNet_with_Attention")
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

input_shape = (224, 224, 3)
mobilenet_model = create_mobilenet_model(input_shape, num_classes=2, learning_rate=0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
history = cnn_model.fit(
    train_gen_new,
    validation_data=valid_gen_new,
    epochs=5,  
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 138s 438ms/step - accuracy: 0.9235 - loss: 0.1907 - val_accuracy: 0.7556 - val_loss: 0.8188
# Epoch 2/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 136s 436ms/step - accuracy: 0.9229 - loss: 0.1967 - val_accuracy: 0.9616 - val_loss: 0.1058
# Epoch 3/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 135s 431ms/step - accuracy: 0.9403 - loss: 0.1481 - val_accuracy: 0.8808 - val_loss: 0.3841
# Epoch 4/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 136s 434ms/step - accuracy: 0.9528 - loss: 0.1146 - val_accuracy: 0.9717 - val_loss: 0.0748
# Epoch 5/5
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 136s 434ms/step - accuracy: 0.9659 - loss: 0.0909 - val_accuracy: 0.9737 - val_loss: 0.0659

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
report = classification_report(test_labels, predicted_classes, target_names=list(test_gen_new.class_indices.keys()))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       244
#            1       0.95      1.00      0.98       251
#
#     accuracy                           0.98       495
#    macro avg       0.98      0.98      0.98       495
# weighted avg       0.98      0.98      0.98       495

# %%
conf_matrix = confusion_matrix(test_labels, predicted_classes)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=list(test_gen_new.class_indices.keys()), yticklabels=list(test_gen_new.class_indices.keys()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
