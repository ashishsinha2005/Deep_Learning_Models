# %%
! yolo task=detect mode=predict model="D:\HOPE\Projects\Object Detection using Yolov8 in Industrial Safety Gears dataset\Yolov8 object detection\runs\detect\train2\weights\best.pt" conf=0.25 source=1.mp4
# Out:
# Ultralytics YOLOv8.2.101 🚀 Python-3.12.6 torch-2.4.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/229) d:\HOPE\Projects\Object Detection using Yolov8 in Industrial Safety Gears dataset\Yolov8 object detection\1.mp4: 128x224 7 Helmets, 1 Jacket, 132.6ms
# video 1/1 (frame 2/229) d:\HOPE\Projects\Object Detection using Yolov8 in Industrial Safety Gears dataset\Yolov8 object detection\1.mp4: 128x224 7 Helmets, 2 Jackets, 82.7ms
# video 1/1 (frame 3/229) d:\HOPE\Projects\Object Detection using Yolov8 in Industrial Safety Gears dataset\Yolov8 object detection\1.mp4: 128x224 7 Helmets, 2 Jackets, 66.2ms
# video 1/1 (frame 4/229) d:\HOPE\Projects\Object Detection using Yolov8 in Industrial Safety Gears dataset\Yolov8 object detection\1.mp4: 128x224 7 Helmets, 1 Jacket, 77.0ms
# ...
